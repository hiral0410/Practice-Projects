# %% [markdown]
# Practice Project-3

# %% [markdown]
# ## Red Wine Quality Prediction

# %% [markdown]
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine.

# %% [markdown]
# ### Attribute Information

# %% [markdown]
# Input variables (based on physicochemical tests):
#
# 1 - fixed acidity
#
# 2 - volatile acidity
#
# 3 - citric acid
#
# 4 - residual sugar
#
# 5 - chlorides
#
# 6 - free sulfur dioxide
#
# 7 - total sulfur dioxide
#
# 8 - density
#
# 9 - pH
#
# 10 - sulphates
#
# 11 - alcohol
#
# Output variable (based on sensory data):
#
# 12 - quality (score between 0 and 10)

# %% [markdown]
# ####  Physicochemicals

# %%
import pandas as pd

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Scatterplot:

# %%
import seaborn as sns
sns.scatterplot(x="fixed acidity",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %% [markdown]
# The quality of fixed acidity variant is good.

# %%
sns.scatterplot(x="volatile acidity",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %% [markdown]
# The quality of volatile acidity variant is good.

# %%
sns.scatterplot(x="citric acid",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %% [markdown]
# The quality of citric acid variant is good.

# %%
sns.scatterplot(x="residual sugar",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %% [markdown]
# The quality of residual sugar variant is good.

# %%
sns.scatterplot(x="chlorides",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %% [markdown]
# The quality of chlorides variant is good.

# %%
sns.scatterplot(x="free sulfur dioxide",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %% [markdown]
# The quality of free sulfur dioxide variant is good.

# %%
sns.scatterplot(x="total sulfur dioxide",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %% [markdown]
# The quality of total sulfur dioxide variant is good.

# %%
sns.scatterplot(x="density",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %% [markdown]
# The quality of density variant is good.

# %%
sns.scatterplot(x="pH",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %% [markdown]
# The quality of pH variant is good.

# %%
sns.scatterplot(x="sulphates",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %% [markdown]
# The quality of sulphates variant is good.

# %%
sns.scatterplot(x="alcohol",y="quality",data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %% [markdown]
# The quality of alcohol variant is good.

# %% [markdown]
# ### Correlation:

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Correlation using heatmap:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt= '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome of Correlation:
#
#     Fixed acid has 12 percent with the target column which is considered as a weak bond. Volatile Acidity has negative 39 percent with the target column which is considered as a very weak bond. Citric Acid has 23 percent with the target column which is considered as a weak bond. Residual sugar has 1 percent with the target column which is considered as a very weak bond. Chlorides has negative 13 percent with the target column which is considered as a very weak bond. Free Sulfur Dioxide has negative 5 percent with the column which is considered as a weak bond. Total Sulfur dioxide has negative 19 percent with the target column which is considered as a weak bond. Density has negative 17 percent with the target column which is considered as a weak bond. pH has negative 6 percent with the target column which is considered as a weak bond. Sulphates has 25 percent with the target column which is considered as a weak bond. Alcohol has 48 percent with the target column which is considered as a good bond.
#
# Max Correlation: Alcohol
#
# Min Correlation: Volatile Acidity

# %% [markdown]
# ### Describing Datasets:

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=16)
plt.yticks(fontsize=10)
plt.title("variables summary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Outcome of the dataset:
#
#     From the above plotting we are determining mean, standard deviation, minimum and maximum value of each column. It helps us further in data cleaning.
#
# Total Number of rows in datasets:
#
# 1. 1599 rows
# 2. 12 columns
#
# Fixed Acidity-
#
# 1. Mean= 8.319637
# 2. Std= 1.741096
# 3. Min= 4.600000
# 4. Max= 15.900000
#
# Volatile Acidity-
#
# 1. Mean= 0.527821
# 2. Std= 0.179060
# 3. Min= 0.120000
# 4. Max= 1.580000
#
# Citric Acid-
#
# 1. Mean= 0.270976
# 2. Std= 0.194801
# 3. Min= 0
# 4. Max= 1
#
# Residual Sugar-
#
# 1. Mean= 2.538806
# 2. Std= 1.409928
# 3. Min= 0.900000
# 4. Max= 15.500000
#
# Chlorides-
#
# 1. Mean= 0.087467
# 2. Std= 0.047065
# 3. Min= 0.012000
# 4. Max= 0.611000
#
# Free Sulfur Dioxide-
#
# 1. Mean= 15.874922
# 2. Std= 10.460157
# 3. Min= 1
# 4. Max= 72.000000
#
# Total Sulfur Dioxide-
#
# 1. Mean= 46.467792
# 2. Std= 32.895324
# 3. Min= 6
# 4. Max= 289.000000
#
# Density-
#
# 1. Mean= 0.996747
# 2. Std= 0.001887
# 3. Min= 0.990070
# 4. Max= 1.003690
#
# pH-
#
# 1. Mean= 3.311113
# 2. Std= 0.154386
# 3. Min= 2.740000
# 4. Max= 4.010000
#
# Silphates-
#
# 1. Mean= 0.658149
# 2. Std= 0.169507
# 3. Min= 0.330000
# 4. Max= 2
#
# Alcohol-
#
# 1. Mean= 10.422983
# 2. Std= 1.065668
# 3. Min= 8.400000
# 4. Max= 14.900000
#
# Quality-
#
# 1. Mean= 5.636023
# 2. Std= 0.807569
# 3. Min= 3
# 4. Max= 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ### Outliers Checking:

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(y=df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# From the above outcome we can see that columns['Citric Acid','Alcohol','Quality'] has less outliers and columns['Fixed Acidity','Volatile Acidity','Residual Sugar','Chlorides','free sulfur dioxiode','total sulfur dioxide','Density','pH','Sulphates'] has more outliers.

# %% [markdown]
# ### Skewness:

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
Outcome of the Skewness:
    
    Skewness threshold is taken

# %% [markdown]
# ### Normal Distribution Curve:

# %%
sns.distplot(df["fixed acidity"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["citric acid"])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["residual sugar"])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["chlorides"])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["free sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["total sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["density"])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["pH"])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["sulphates"])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["alcohol"])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %%
sns.distplot(df["quality"])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Density'>

# %% [markdown]
# The data of the column is not normalised.The building blocks is out of the normalised curve.

# %% [markdown]
# The Normal Distribution shoes that the data is skewed.
